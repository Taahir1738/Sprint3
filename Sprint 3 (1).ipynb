# %%
#Connect jupyter to mysql
import mysql.connector
mydb =mysql.connector.connect(host="localhost", user="root", passwd="Taahir123")
print(mydb)
# Out:
# <mysql.connector.connection.MySQLConnection object at 0x0000020E10E1DC08>

# %%
#Test connection
if (mydb):
    print("Connection Successful")
    
else:
    print("Connection Unsuccessful")
# Out:
# Connection Successful

# %%
#Create database named exra
import mysql.connector
mydb =mysql.connector.connect(host="localhost", user="root", passwd="Taahir123")
#object mycursor
mycursor =mydb.cursor()
mycursor.execute("Create database Extra")
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-3-36bfeac45267> in <module>
#       4 #object mycursor
#       5 mycursor =mydb.cursor()
# ----> 6 mycursor.execute("Create database Extra")
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     549         else:
#     550             try:
# --> 551                 self._handle_result(self._connection.cmd_query(stmt))
#     552             except errors.InterfaceError:
#     553                 if self._connection._have_next_result:  # pylint: disable=W0212
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     488         if not isinstance(query, bytes):
#     489             query = query.encode('utf-8')
# --> 490         result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     491
#     492         if self._have_next_result:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\mysql\connector\connection.py in _handle_result(self, packet)
#     393             return self._handle_eof(packet)
#     394         elif packet[4] == 255:
# --> 395             raise errors.get_exception(packet)
#     396
#     397         # We have a text result set
#
# DatabaseError: 1007 (HY000): Can't create database 'extra'; database exists

# %%
#Creating 2 tables. Cost price and Barcode
import mysql.connector
mydb =mysql.connector.connect(host="localhost", user="root", passwd="Taahir123", database="extra")
mycursor =mydb.cursor()
mycursor.execute("Create table Add_on(Cost_Price varchar(200), Barcode int(20))")

# %%
#("Show database) 
import mysql.connector
mydb =mysql.connector.connect(host="localhost", user="root", passwd="Taahir123")
mycursor =mydb.cursor()

mycursor.execute("Show databases")
for db in mycursor:
    print(db)
# Out:
# ('data',)
# ('extra',)
# ('information_schema',)
# ('mydatabase',)
# ('mysql',)
# ('new_schema',)
# ('performance_schema',)
# ('sakila',)
# ('sys',)
# ('world',)

# %%
#Show tables
import mysql.connector
mydb =mysql.connector.connect(host="localhost", user="root", passwd="Taahir123", database="extra")
mycursor =mydb.cursor()
mycursor.execute("Show tables")

for tb in mycursor:
    print(tb)
# Out:
# ('add_on',)
# ('cost_price',)

# %%
#Insert command
import mysql.connector

mydb =mysql.connector.connect(host="localhost", user="root", passwd="Taahir123", database="mydatabase")
mycursor =mydb.cursor()

sqlform = "INSERT INTO book2(Chips, Quantity) VALUES (%s, %s)"

cost = [
    ("Conachos", 101),
    ("Spookies", 102),
    ("Cracka Snack", 103),
    ("Chippa", 104),
    ("Bigga", 105),
    ("Flyers", 106),
    ("Stylos", 107),
    ("Bubbles", 108),
    ("Labamba", 109),
    ("Fritos", 110)
]

mycursor.executemany(sqlform, cost)

mydb.commit()

# %%
#Insert command
import mysql.connector

mydb =mysql.connector.connect(host="localhost", user="root", passwd="Taahir123", database="mydatabase")
mycursor =mydb.cursor()

sqlform = "ALTER TABLE book2 ADD Quantity_Value Varchar(50)"


mycursor.execute(sqlform)

mydb.commit()

# %%
import mysql.connector
import pandas as pd

mydb =mysql.connector.connect(host="localhost", user="root", passwd="Taahir123", database="mydatabase")
mycursor =mydb.cursor()

df = pd.read_sql_query("SELECT * From book2 WHERE Cooldrink = ''",mydb) # Importing a SQL Data Query into a Pandas DataFrame
df

alter = df.to_csv('Chips.csv', index = False)
new = pd.read_csv("Chips.csv")
new
# Out:
# Empty DataFrame
# Columns: [Chips, Quantity, Price, Cooldrink, Quantity_[0], Price_[0], Chocolate, Quantity_[1], Price_[1], Pies, Quantity_[2], Price_[2], Fruit, Quantity_[3], Price_[3], Cupcakes, Quantity_[4], Price_[4], Veggies, Quantity_[5], Price_[5], Quantity_Value]
# Index: []
#
# [0 rows x 22 columns]

# %%
#LIMIT 5
import mysql.connector
import pandas as pd

mydb =mysql.connector.connect(host="localhost", user="root", passwd="Taahir123", database="mydatabase")
mycursor =mydb.cursor()

df = pd.read_sql_query("SELECT Chips,Quantity,Price FROM mydatabase.book2 LIMIT 5;",mydb)
alter = df.to_csv('Chips.csv', index = False)
new = pd.read_csv("Chips.csv")
new
# Out:
#       Chips  Quantity   Price
# 0     Simba         2   R4,50
# 1      Lays         4   R6,00
# 2  Willards         6   R5,00
# 3  Pringles         8  R10,00
# 4   Doritos        10   R6,00

# %%
import mysql.connector
import pandas as pd

mydb =mysql.connector.connect(host="localhost", user="root", passwd="Taahir123", database="mydatabase")
mycursor =mydb.cursor()

df = pd.read_sql_query("SELECT Chips,Quantity,Price FROM mydatabase.book2;",mydb)
alter = df.to_csv('Chips.csv', index = False)
new = pd.read_csv("Chips.csv")
new
# Out:
#            Chips  Quantity   Price
# 0          Simba         2   R4,50
# 1           Lays         4   R6,00
# 2       Willards         6   R5,00
# 3       Pringles         8  R10,00
# 4        Doritos        10   R6,00
# 5       Nik Naks        14   R2,00
# 6       IQ Foods         9   R1,50
# 7        Walkers        10   R2,00
# 8          Truda        12   R2,00
# 9       Conachos       101     NaN
# 10      Spookies       102     NaN
# 11  Cracka Snack       103     NaN
# 12        Chippa       104     NaN
# 13         Bigga       105     NaN
# 14        Flyers       106     NaN
# 15        Stylos       107     NaN
# 16       Bubbles       108     NaN
# 17       Labamba       109     NaN
# 18        Fritos       110     NaN
# 19      Conachos       101     NaN
# 20      Spookies       102     NaN
# 21  Cracka Snack       103     NaN
# 22        Chippa       104     NaN
# 23         Bigga       105     NaN
# 24        Flyers       106     NaN
# 25        Stylos       107     NaN
# 26       Bubbles       108     NaN
# 27       Labamba       109     NaN
# 28        Fritos       110     NaN
# 29      Conachos       101     NaN
# 30      Spookies       102     NaN
# 31  Cracka Snack       103     NaN
# 32        Chippa       104     NaN
# 33         Bigga       105     NaN
# 34        Flyers       106     NaN
# 35        Stylos       107     NaN
# 36       Bubbles       108     NaN
# 37       Labamba       109     NaN
# 38        Fritos       110     NaN
